# %%
num = 100

# %%
num
# Out:
# 100

# %%
num = 80

# %%
print(num)
# Out:
# 80

# %%
num_class = 20

# %%
num_class
# Out:
# 20

# %%
_num = 100

# %%
num
# Out:
# 80

# %%
_num
# Out:
# 100

# %%
chuoi = "Type, id"

# %%
type(chuoi)
# Out:
# str

# %%
chuoi1 = 'type, id'

# %%
type(chuoi1)
# Out:
# str

# %%
id(chuoi)
# Out:
# 2834008076720

# %%
id(chuoi1)
# Out:
# 2834012060080

# %%
chuoi2 = "Type, id"

# %%
type(chuoi2), id(chuoi2)
# Out:
# (str, 2834007317296)

# %%
num = 2022

# %%
type(num), id(num)
# Out:
# (int, 2834023111440)

# %%
so = 2022

# %%
type(so), id(so)
# Out:
# (int, 2834023112144)

# %%
n1 = "Tuan"

# %%
n2 = "Tuan"

# %%
id(n1), id(n2)
# Out:
# (2834007675504, 2834007675504)

# %%
so1 = 2011
so2 = 2011
id(so1), id(so2)
# Out:
# (2834014614192, 2834014614288)

# %%
m1 = 5
m2 = 5
id(m1), id(m2)
# Out:
# (2833926941104, 2833926941104)

# %%
# Boolean

# %%
giatri = True

# %%
type(giatri)
# Out:
# bool

# %%
giatri = Fale
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <module>
# ----> 1 giatri = Fale
#
# NameError: name 'Fale' is not defined

# %%
giatri = False

# %%
type(giatro)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 type(giatro)
#
# NameError: name 'giatro' is not defined

# %%
type(giatri)
# Out:
# bool
