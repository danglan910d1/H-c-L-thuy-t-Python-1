# %%
a = {"name": "Đặng Thị Ngọc Lan", "age": "20", "name1": "Trần Thị Thu Hà", "age1": "23" }
print(a, type(a), id(a), len(a))
# Out:
# {'name': 'Đặng Thị Ngọc Lan', 'age': '20', 'name1': 'Trần Thị Thu Hà', 'age1': '23'} <class 'dict'> 140137019997552 4

# %%
a["age"]
# Out:
# '20'

# %%
# Thay đổi giá trị của key
a["age"] = 23
a
# Out:
# {'age': 23,
#  'age1': '23',
#  'name': 'Đặng Thị Ngọc Lan',
#  'name1': 'Trần Thị Thu Hà'}

# %%
# Xóa phần tử trong dict
del a["age"]
a
# Out:
# {'age1': '23', 'name': 'Đặng Thị Ngọc Lan', 'name1': 'Trần Thị Thu Hà'}

# %%
# Kiểm tra phần tử có trong dict không thì kiểm tra key
"age" in a, "name" in a, "name1" in a, "age" not in a, "Trần Thị Thu Hà" not in a
# Out:
# (False, True, True, True, True)

# %%
# Xóa tất cả phần tử dùng hàm clear
b = {"name": "Cảnh Quân Xuyên"}
b.clear()
b
# Out:
# {}

# %%
# Xóa phần tử trong dict bằng hàm pop
a1 = {"name": "Đặng Thị Ngọc Lan", "age": "20", "name1": "Trần Thị Thu Hà", "age1": "23", "name2": "Cảnh Quân Xuyên" }
print(a1.pop("name2"))
print(a1)
# Out:
# Cảnh Quân Xuyên
# {'name': 'Đặng Thị Ngọc Lan', 'age': '20', 'name1': 'Trần Thị Thu Hà', 'age1': '23'}

# %%
# Xóa ngẫu nhiên
a1.popitem()
# Out:
# ('age1', '23')
