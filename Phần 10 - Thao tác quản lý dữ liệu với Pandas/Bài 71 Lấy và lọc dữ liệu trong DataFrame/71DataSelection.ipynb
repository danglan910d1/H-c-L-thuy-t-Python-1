# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randint
df1 = pd.read_clipboard()
df1
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# D     3    75    19    38    64    80
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
# Lấy dữ liệu cột
df1['col1']
# Out:
# A    18
# B    41
# C    12
# D     3
# E    71
# F    25
# Name: col1, dtype: int64

# %%
df1['col5']
# Out:
# A    16
# B    10
# C    12
# D    64
# E    97
# F    44
# Name: col5, dtype: int64

# %%
# Lấy dữ liệu n cột
df1[['col3', 'col5']]
# Out:
#    col3  col5
# A    13    16
# B    11    10
# C    41    12
# D    19    64
# E    72    97
# F    83    44

# %%
# Lấy dữ liệu có giá trị thỏa điều kiện thì sẽ bỏ hàng thuộc cột không thỏa
df1[df1['col4'] > 50 ]
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
# Kiểm tra dữ liệu theo điều kiện
df1 > 50
# Out:
#     col1   col2   col3   col4   col5   col6
# A  False   True  False   True  False   True
# B  False  False  False   True  False   True
# C  False   True  False   True  False  False
# D  False   True  False  False   True   True
# E   True   True   True   True   True   True
# F  False   True   True   True  False   True

# %%
df1
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# D     3    75    19    38    64    80
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
# Lọc dữ liệu hàng
df1.iloc[4]
# Lọc dữ liệu cột
# Out:
# col1    71
# col2    91
# col3    72
# col4    81
# col5    97
# col6    65
# Name: E, dtype: int64
