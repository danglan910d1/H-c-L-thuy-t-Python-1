# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import randint
df1 = pd.read_clipboard()
df1
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# D     3    75    19    38    64    80
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
# Lấy dữ liệu cột
df1['col1']
# Out:
# A    18
# B    41
# C    12
# D     3
# E    71
# F    25
# Name: col1, dtype: int64

# %%
df1['col5']
# Out:
# A    16
# B    10
# C    12
# D    64
# E    97
# F    44
# Name: col5, dtype: int64

# %%
# Lấy dữ liệu n cột
df1[['col3', 'col5']]
# Out:
#    col3  col5
# A    13    16
# B    11    10
# C    41    12
# D    19    64
# E    72    97
# F    83    44

# %%
# Lấy dữ liệu có giá trị thỏa điều kiện thì sẽ bỏ hàng thuộc cột không thỏa
df1[df1['col4'] > 50 ]
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
# Kiểm tra dữ liệu theo điều kiện
df1 > 50
# Out:
#     col1   col2   col3   col4   col5   col6
# A  False   True  False   True  False   True
# B  False  False  False   True  False   True
# C  False   True  False   True  False  False
# D  False   True  False  False   True   True
# E   True   True   True   True   True   True
# F  False   True   True   True  False   True

# %%
df1
# Out:
#    col1  col2  col3  col4  col5  col6
# A    18    61    13    68    16    94
# B    41    20    11    52    10    82
# C    12    61    41    99    12    28
# D     3    75    19    38    64    80
# E    71    91    72    81    97    65
# F    25    52    83    76    44    95

# %%
df1.ix['E']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\landang\Lập trình Python từ hero-zero\Phần 10 - Thao tác quản lý dữ liệu với Pandas\Bài 71 Lấy và lọc dữ liệu trong DataFrame\71DataSelection.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/f%3A/landang/L%E1%BA%ADp%20tr%C3%ACnh%20Python%20t%E1%BB%AB%20hero-zero/Ph%E1%BA%A7n%2010%20-%20Thao%20t%C3%A1c%20qu%E1%BA%A3n%20l%C3%BD%20d%E1%BB%AF%20li%E1%BB%87u%20v%E1%BB%9Bi%20Pandas/B%C3%A0i%2071%20L%E1%BA%A5y%20v%C3%A0%20l%E1%BB%8Dc%20d%E1%BB%AF%20li%E1%BB%87u%20trong%20DataFrame/71DataSelection.ipynb#ch0000007?line=0'>1</a> df1.ix['E']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5575'>5576</a> if (
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5576'>5577</a>     name not in self._internal_names_set
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5577'>5578</a>     and name not in self._metadata
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5578'>5579</a>     and name not in self._accessors
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5579'>5580</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5580'>5581</a> ):
#    <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5581'>5582</a>     return self[name]
# -> <a href='file:///~/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0/LocalCache/local-packages/Python310/site-packages/pandas/core/generic.py?line=5582'>5583</a> return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
